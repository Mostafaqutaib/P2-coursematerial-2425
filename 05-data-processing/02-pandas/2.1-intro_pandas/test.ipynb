# %%
import pandas as pd
my_series = pd.Series({
    'London': 10,
    'Tripoli': 100,
    'Cairo': 10
})
my_series
# Out:
# np.int64(100)

# %%
# Out:
# Tripoli    100
# dtype: int64

# %%
my_series[my_series > 10]
# Out:
# Tripoli    100
# dtype: int64
