# %% [markdown]
# # Data Analysis: Movie Ticket Sales
#
# In the file movie_ticket_sales.csv, you will find data about movie ticket sales. Your task is to clean and analyze this data. Use the provided code fields under each task to write down your code. Do not remove the comments already present.

# %% [markdown]
# #### 1. Import Required Libraries
# Import the necessary Python libraries for data analysis and visualization.

# %% [markdown]
# #### 2. Load the Dataset
# Load the movie ticket sales dataset into a Pandas DataFrame named df_tickets.

# %% [markdown]
# #### 3. Explore the Data
# - Display the first rows of the DataFrame to understand its structure without slicing.
# - Remove any unnamed column from the DataFrame.

# %% [markdown]
# #### 4. Data Cleaning
# - Convert the column show_date to pandas datetime objects.
# - Add a new column is_weekend, indicating whether the ticket was sold on a weekend. A weekend includes Saturday and Sunday. Use the show_date column to determine this.

# %% [markdown]
# #### 5. Average Revenue by Movie
# Calculate and display the **average revenue** earned per movie title in one line of code.

# %% [markdown]
# #### 6. Analyze Popular Movies
# - Identify the top 3 most sold movie titles (based on ticket quantity).
# - Create separate DataFrames for each of these movies, naming them df_ followed by the movie's name (e.g., df_inception). Include only the following columns: show_date, movie_title, quantity, price_per_ticket, and total_revenue.

# %% [markdown]
# #### 7. Revenue Analysis
# Visualize the **daily total revenue** for the first quarter of 2020 (January 1 to March 31). Your plot should include:
#
# - **Daily revenue trend in blue.**
# - A title: "Daily Movie Revenue (Q1 2020)".
# - Proper axis labels: "Date" (x-axis) and "Revenue (€)" (y-axis).
# - Ensure gridlines are visible for better readability.
# - Add month indicators on the x-axis, labeled with month abbreviations (Jan, Feb, etc.) at the start of each month's data.
