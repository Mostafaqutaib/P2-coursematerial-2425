# %% [markdown]
# # Data analysis: Pizza sales
#
# In het bestand pizza_orders.csv vind je gegevens over pizzabestellingen. Je taak is om deze gegevens op te schonen en te analyseren. Gebruik de meegeleverde codevelden onder de taken om je code op te schrijven. Verwijder de al aanwezige opmerkingen niet.

# %% [markdown]
# Importeer de benodigde Python-pakketten voor deze data-analyse.

# %% [markdown]
# Laad de Pizza Order Dataset in een DataFrame genaamd `df_pizza`.

# %% [markdown]
# Toon de eerste rijen van het DataFrame om de structuur te begrijpen. Gebruik hiervoor geen slicing.

# %%
# Out:
#    Unnamed: 0  X           id        date      time         name size  \
# 0           1  1  2015-000001  2015-01-01  11:38:36     hawaiian    M
# 1           2  2  2015-000002  2015-01-01  11:57:40  classic_dlx    M
# 2           3  3  2015-000002  2015-01-01  11:57:40     mexicana    M
# 3           4  4  2015-000002  2015-01-01  11:57:40     thai_ckn    L
# 4           5  5  2015-000002  2015-01-01  11:57:40  five_cheese    L
#
#       type  price
# 0  classic  13.25
# 1  classic  16.00
# 2   veggie  16.00
# 3  chicken  20.75
# 4   veggie  18.50

# %% [markdown]
# Verwijder de naamloze kolom uit het DataFrame.

# %% [markdown]
# Wijzig de datums in de datumkolom naar pandas datetime-objecten.

# %% [markdown]
# Voeg een nieuwe kolom "is_large" toe die aangeeft of de pizzagrootte 'Large' is. Een pizza is groot wanneer de waarde in de kolom 'size' gelijk is aan "L".

# %% [markdown]
# Toon de gemiddelde prijs per pizzatype. (Doe dit in één regel code.)

# %%
# Out:
# type
# chicken    17.704175
# classic    14.800236
# supreme    17.391508
# veggie     16.629448
# Name: price, dtype: float64

# %% [markdown]
# Maak aparte DataFrames voor de 4 meest bestelde pizza's. Grootte is niet relevant. Noem ze "df_" gevolgd door hun naam. Bijvoorbeeld: df_four_cheese. Alleen de volgende kolommen opnemen: date, time, name, size, type, price.

# %% [markdown]
# ### Revenue in first half of 2015

# %% [markdown]
# Visualiseer de totale omzet die is behaald in de eerste helft van 2015. Zorg ervoor dat de dagelijkse gegevens worden weergegeven. Omzet wordt op de y-as in euro's weergegeven, tijd op de x-as. Includeer het volgende:
#
# * Totale omzet in zwart
# * Toon een legenda met passende labels zodat duidelijk is welke gegevens worden weergegeven
# * Zorg voor correcte aslabels en een titel
# * Op de x-as, zorg voor aanduidingen voor elke maand, gelabeld met de afkorting van de maand in het Engels (Jan, Feb, Mar, enz.). De tick wordt geplaatst aan het begin van de gegevens van de maand.
# * Toon een grid
