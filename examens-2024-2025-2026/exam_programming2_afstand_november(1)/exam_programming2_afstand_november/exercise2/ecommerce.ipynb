# %% [markdown]
# # E-commerce Customer Behavior
#
# You have to analyze E-commerce Customer Behavior data that we provided.

# %% [markdown]
# Import the necessary packages.

# %% [markdown]
# * Load the e-commerce customer behavior dataset into a DataFrame.
# * Give a summary statistics (count, mean, std, min, 25%, 50%, 75%, max) for numeric columns in the DataFrame.

# %% [markdown]
# * Change the dates in the DATE column to pandas datetime objects.
# * Only include the rows with data from 2015.

# %% [markdown]
# Replace all NaN's with 0.

# %% [markdown]
# Plot the data using a graph with on the x-axis the release dates and on the y-axis the engagment time of the customer on that data.
#
# * Use appropriate labels and titles
# * Change the color of the graph to green
# * Show a grid
# * Show the legend
